# %% [markdown]
# UNIVARIATE feature selection method

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/train.csv")

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
x=df.iloc[:,0:20]
y=df.iloc[:,-1]

# %%
x.shape
# Out:
# (2000, 20)

# %%
y.shape
# Out:
# (2000,)

# %%
x # x is independent and y is dependent i.e output price range
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
# perform feature selection method first is applying selectkBest
best_features=SelectKBest(score_func=chi2,k=10)

# %%
fit=best_features.fit(x,y)

# %%
fit.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %%
dfscores=pd.DataFrame(fit.scores_)
dfcolumns=pd.DataFrame(x.columns)

# %%
dfcolumns
# Out:
#                 0
# 0   battery_power
# 1            blue
# 2     clock_speed
# 3        dual_sim
# 4              fc
# 5          four_g
# 6      int_memory
# 7           m_dep
# 8       mobile_wt
# 9         n_cores
# 10             pc
# 11      px_height
# 12       px_width
# 13            ram
# 14           sc_h
# 15           sc_w
# 16      talk_time
# 17        three_g
# 18   touch_screen
# 19           wifi

# %%
featurescores=pd.concat([dfcolumns,dfscores],axis=1)
featurescores.columns=['Features','Score']
featurescores
# Out:
#          Features          Score
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
featurescores.sort_values(by='Score',ascending=False)
# Out:
#          Features          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878
# 10             pc       9.186054
# 9         n_cores       9.097556
# 18   touch_screen       1.928429
# 5          four_g       1.521572
# 7           m_dep       0.745820
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 19           wifi       0.422091
# 17        three_g       0.327643

# %% [markdown]
# Features Importance method

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %%
model= RandomForestClassifier()
model.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
model.feature_importances_
# Out:
# array([0.07548778, 0.00703538, 0.02801003, 0.00667063, 0.02463461,
#        0.00615905, 0.03791724, 0.0248556 , 0.03874832, 0.02351686,
#        0.02966539, 0.05607629, 0.05753014, 0.48002617, 0.02702868,
#        0.02894994, 0.02865051, 0.00545492, 0.00719001, 0.00639248])

# %%
featureimportanve=pd.DataFrame(model.feature_importances_,index=x.columns,columns=['importance'])

# %%
featureimportanve.sort_values(by='importance',ascending=False)
# Out:
#                importance
# ram              0.480026
# battery_power    0.075488
# px_width         0.057530
# px_height        0.056076
# mobile_wt        0.038748
# int_memory       0.037917
# pc               0.029665
# sc_w             0.028950
# talk_time        0.028651
# clock_speed      0.028010
# sc_h             0.027029
# m_dep            0.024856
# fc               0.024635
# n_cores          0.023517
# touch_screen     0.007190
# blue             0.007035
# dual_sim         0.006671
# wifi             0.006392
# four_g           0.006159
# three_g          0.005455

# %%
plt.figure(figsize=(20,10))
plt.bar(featureimportanve.index,featureimportanve['importance'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# corelation matrix  method

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >
